# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %matplotlib notebook

# %%
Src_img = mpimg.imread('robocam_1.jpg') 
plt.imshow(Src_img)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="557">
